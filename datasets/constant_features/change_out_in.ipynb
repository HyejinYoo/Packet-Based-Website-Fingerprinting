# %%
import pandas as pd

# 파일 경로 설정

no_nor_constant_c = 'C:/Users/bje57/datasets/constant_features/no_nor_constant_c.csv'  # 파일의 실제 경로로 변경해주세요.
no_nor_constant_o = 'C:/Users/bje57/datasets/constant_features/no_nor_constant_o.csv'  # 파일의 실제 경로로 변경해주세요.
nor_constant_c = 'C:/Users/bje57/datasets/constant_features/nor_constant_c.csv'  # 파일의 실제 경로로 변경해주세요.
nor_constant_o = 'C:/Users/bje57/datasets/constant_features/nor_constant_o.csv'  # 파일의 실제 경로로 변경해주세요.


# CSV 파일을 DataFrame으로 불러오기
no_nor_constant_c = pd.read_csv(no_nor_constant_c)
no_nor_constant_o = pd.read_csv(no_nor_constant_o)
nor_constant_c = pd.read_csv(nor_constant_c)
nor_constant_o = pd.read_csv(nor_constant_o)

# 데이터 확인
#print(no_nor_constant_c.head())  # 상위 데이터 몇 개 출력
#print(no_nor_constant_o.head())  # 상위 데이터 몇 개 출력
print(nor_constant_c.head())  # 상위 데이터 몇 개 출력
#print(nor_constant_o.head())  # 상위 데이터 몇 개 출력
# Out:
#    std_dev_out_c  std_dev_in_c  avg_out_c  avg_in_c  in_pack_num_c  \
# 0         0.4936        0.0225     0.6810    0.0494         0.0272
# 1         0.3388        0.0223     0.8419    0.0631         0.0175
# 2         0.4748        0.0192     0.6887    0.0496         0.0264
# 3         0.4954        0.0165     0.6836    0.0471         0.0274
# 4         0.4572        0.0172     0.6881    0.0408         0.0257
#
#    out_pack_num_c  in_pack_ratio_c  out_pack_ratio_c  total_pack_num_c  \
# 0          0.1318           0.1153            0.8847            0.1379
# 1          0.0427           0.2600            0.7400            0.0471
# 2          0.1256           0.1195            0.8805            0.1315
# 3          0.1343           0.1132            0.8868            0.1404
# 4          0.1309           0.1090            0.8910            0.1364
#
#    total_pack_sum_c  ...  avg_med_c  sum_burst_med_c  avg_burst_med_c  \
# ...

# %%
nor_constant_c = nor_constant_c.rename(columns={'std_dev_out_c': 'std_dev_in_c', 'std_dev_in_c': 'std_dev_out_c'})
nor_constant_c = nor_constant_c.rename(columns={'avg_out_c': 'avg_in_c', 'avg_in_c': 'avg_out_c'})
nor_constant_c = nor_constant_c.rename(columns={'in_sum_30_c': 'out_sum_30_c', 'out_sum_30_c': 'in_sum_30_c'})
nor_constant_c = nor_constant_c.rename(columns={'in_num_30_c': 'out_num_30_c', 'out_num_30_c': 'in_num_30_c'})
nor_constant_c = nor_constant_c.rename(columns={'in_pack_sum_c': 'out_pack_sum_c', 'out_pack_sum_c': 'in_pack_sum_c'})
nor_constant_c = nor_constant_c.rename(columns={'in_pack_ratio_c': 'out_pack_ratio_c', 'out_pack_ratio_c': 'in_pack_ratio_c'})
nor_constant_c = nor_constant_c.rename(columns={'in_pack_num_c': 'out_pack_num_c', 'out_pack_num_c': 'in_pack_num_c'})

# %%
print(nor_constant_c.head())  # 상위 데이터 몇 개 출력
# Out:
#    std_dev_in_c  std_dev_out_c  avg_in_c  avg_out_c  out_pack_num_c  \
# 0        0.4936         0.0225    0.6810     0.0494          0.0272
# 1        0.3388         0.0223    0.8419     0.0631          0.0175
# 2        0.4748         0.0192    0.6887     0.0496          0.0264
# 3        0.4954         0.0165    0.6836     0.0471          0.0274
# 4        0.4572         0.0172    0.6881     0.0408          0.0257
#
#    in_pack_num_c  out_pack_ratio_c  in_pack_ratio_c  total_pack_num_c  \
# 0         0.1318            0.1153           0.8847            0.1379
# 1         0.0427            0.2600           0.7400            0.0471
# 2         0.1256            0.1195           0.8805            0.1315
# 3         0.1343            0.1132           0.8868            0.1404
# 4         0.1309            0.1090           0.8910            0.1364
#
#    total_pack_sum_c  ...  avg_med_c  sum_burst_med_c  avg_burst_med_c  \
# ...

# %%
no_nor_constant_c = no_nor_constant_c.rename(columns={'std_dev_out_c': 'std_dev_in_c', 'std_dev_in_c': 'std_dev_out_c'})
no_nor_constant_c = no_nor_constant_c.rename(columns={'avg_out_c': 'avg_in_c', 'avg_in_c': 'avg_out_c'})
no_nor_constant_c = no_nor_constant_c.rename(columns={'in_sum_30_c': 'out_sum_30_c', 'out_sum_30_c': 'in_sum_30_c'})
no_nor_constant_c = no_nor_constant_c.rename(columns={'in_num_30_c': 'out_num_30_c', 'out_num_30_c': 'in_num_30_c'})
no_nor_constant_c = no_nor_constant_c.rename(columns={'in_pack_sum_c': 'out_pack_sum_c', 'out_pack_sum_c': 'in_pack_sum_c'})
no_nor_constant_c = no_nor_constant_c.rename(columns={'in_pack_ratio_c': 'out_pack_ratio_c', 'out_pack_ratio_c': 'in_pack_ratio_c'})
no_nor_constant_c = no_nor_constant_c.rename(columns={'in_pack_num_c': 'out_pack_num_c', 'out_pack_num_c': 'in_pack_num_c'})

# %%
nor_constant_o = nor_constant_o.rename(columns={'std_dev_out_o': 'std_dev_in_o', 'std_dev_in_o': 'std_dev_out_o'})
nor_constant_o = nor_constant_o.rename(columns={'avg_out_o': 'avg_in_o', 'avg_in_o': 'avg_out_o'})
nor_constant_o = nor_constant_o.rename(columns={'in_sum_30_o': 'out_sum_30_o', 'out_sum_30_o': 'in_sum_30_o'})
nor_constant_o = nor_constant_o.rename(columns={'in_num_30_o': 'out_num_30_o', 'out_num_30_o': 'in_num_30_o'})
nor_constant_o = nor_constant_o.rename(columns={'in_pack_sum_o': 'out_pack_sum_o', 'out_pack_sum_o': 'in_pack_sum_o'})
nor_constant_o = nor_constant_o.rename(columns={'in_pack_ratio_o': 'out_pack_ratio_o', 'out_pack_ratio_o': 'in_pack_ratio_o'})
nor_constant_o = nor_constant_o.rename(columns={'in_pack_num_o': 'out_pack_num_o', 'out_pack_num_o': 'in_pack_num_o'})

# %%
no_nor_constant_o = no_nor_constant_o.rename(columns={'std_dev_out_o': 'std_dev_in_o', 'std_dev_in_o': 'std_dev_out_o'})
no_nor_constant_o = no_nor_constant_o.rename(columns={'avg_out_o': 'avg_in_o', 'avg_in_o': 'avg_out_o'})
no_nor_constant_o = no_nor_constant_o.rename(columns={'in_sum_30_o': 'out_sum_30_o', 'out_sum_30_o': 'in_sum_30_o'})
no_nor_constant_o = no_nor_constant_o.rename(columns={'in_num_30_o': 'out_num_30_o', 'out_num_30_o': 'in_num_30_o'})
no_nor_constant_o = no_nor_constant_o.rename(columns={'in_pack_sum_o': 'out_pack_sum_o', 'out_pack_sum_o': 'in_pack_sum_o'})
no_nor_constant_o = no_nor_constant_o.rename(columns={'in_pack_ratio_o': 'out_pack_ratio_o', 'out_pack_ratio_o': 'in_pack_ratio_o'})
no_nor_constant_o = no_nor_constant_o.rename(columns={'in_pack_num_o': 'out_pack_num_o', 'out_pack_num_o': 'in_pack_num_o'})

# %%
print(no_nor_constant_c.head())  # 상위 데이터 몇 개 출력
print(no_nor_constant_o.head())  # 상위 데이터 몇 개 출력
print(nor_constant_c.head())  # 상위 데이터 몇 개 출력
print(nor_constant_o.head())  # 상위 데이터 몇 개 출력
# Out:
#    std_dev_in_c  std_dev_out_c  avg_in_c  avg_out_c  out_pack_num_c  \
# 0      8804.074        583.467 -8533.333    794.256             121
# 1      6234.214        577.670 -4771.404    871.489              80
# 2      8491.051        501.069 -8353.684    794.947             118
# 3      8833.261        435.764 -8473.600    780.800             122
# 4      8199.242        452.094 -8366.987    745.316             115
#
#    in_pack_num_c  out_pack_ratio_c  in_pack_ratio_c  total_pack_num_c  \
# 0           1300             0.085            0.915              1421
# 1            438             0.154            0.846               518
# 2           1240             0.087            0.913              1358
# 3           1324             0.084            0.916              1446
# 4           1291             0.082            0.918              1406
#
#    total_pack_sum_c  ...  avg_med_c  sum_burst_med_c  avg_burst_med_c  \
# ...

# %%
no_nor_constant_c.to_csv('mod_no_nor_constant_c.csv', index=False)
no_nor_constant_o.to_csv('mod_no_nor_constant_o.csv', index=False)

nor_constant_c.to_csv('mod_nor_constant_c.csv', index=False)
nor_constant_o.to_csv('mod_nor_constant_o.csv', index=False)

# %%
import pandas as pd

# 파일 경로 설정

features_closed_p = 'C:/Users/bje57/ml_data/features_closed.csv'  # 파일의 실제 경로로 변경해주세요.
features_open_p = 'C:/Users/bje57/ml_data/features_open.csv'  # 파일의 실제 경로로 변경해주세요.
y_mon_p = 'C:/Users/bje57/ml_data/y_mon.csv'  # 파일의 실제 경로로 변경해주세요.
y_bin_p = 'C:/Users/bje57/ml_data/y_bin.csv'  # 파일의 실제 경로로 변경해주세요.
y_mul_p = 'C:/Users/bje57/ml_data/y_mul.csv'  # 파일의 실제 경로로 변경해주세요.


# CSV 파일을 DataFrame으로 불러오기
features_closed = pd.read_csv(features_closed_p)
features_open = pd.read_csv(features_open_p)
y_mon = pd.read_csv(y_mon_p)
y_bin = pd.read_csv(y_bin_p)
y_mul = pd.read_csv(y_mul_p)

# 데이터 확인
print(features_closed.head())  # 상위 데이터 몇 개 출력
print(features_open.head())  # 상위 데이터 몇 개 출력
print(y_mon.head())  # 상위 데이터 몇 개 출력
print(y_bin.head())  # 상위 데이터 몇 개 출력
print(y_mul.head())  # 상위 데이터 몇 개 출력

# 첫번째 열 드롭

features_closed = features_closed.drop(columns='Unnamed: 0')
features_open = features_open.drop(columns='Unnamed: 0')
y_mon = y_mon.drop(columns='Unnamed: 0')
y_bin = y_bin.drop(columns='Unnamed: 0')
y_mul = y_mul.drop(columns='Unnamed: 0')

print(y_bin)
for idx, i in enumerate(y_bin['y']) : # y_mul -1 전처리
    y_mul['y'][idx]=i
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[2], line 13
#       9 y_mul_p = 'C:/Users/bje57/ml_data/y_mul.csv'  # 파일의 실제 경로로 변경해주세요.
#      12 # CSV 파일을 DataFrame으로 불러오기
# ---> 13 features_closed = pd.read_csv(features_closed_p)
#      14 features_open = pd.read_csv(features_open_p)
#      15 y_mon = pd.read_csv(y_mon_p)
#
# File ~\anaconda3\Lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:950, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     946     defaults={"delimiter": ","},
#     947 )
#     948 kwds.update(kwds_defaults)
# --> 950 return _read(filepath_or_buffer, kwds)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:611, in _read(filepath_or_buffer, kwds)
#     608     return parser
#     610 with parser:
# --> 611     return parser.read(nrows)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1778, in TextFileReader.read(self, nrows)
#    1771 nrows = validate_integer("nrows", nrows)
#    1772 try:
#    1773     # error: "ParserBase" has no attribute "read"
#    1774     (
#    1775         index,
#    1776         columns,
#    1777         col_dict,
# -> 1778     ) = self._engine.read(  # type: ignore[attr-defined]
#    1779         nrows
#    1780     )
#    1781 except Exception:
#    1782     self.close()
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\c_parser_wrapper.py:230, in CParserWrapper.read(self, nrows)
#     228 try:
#     229     if self.low_memory:
# --> 230         chunks = self._reader.read_low_memory(nrows)
#     231         # destructive to chunks
#     232         data = _concatenate_chunks(chunks)
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\parsers.pyx:808, in pandas._libs.parsers.TextReader.read_low_memory()
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\parsers.pyx:866, in pandas._libs.parsers.TextReader._read_rows()
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\parsers.pyx:852, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\parsers.pyx:1973, in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: out of memory

# %%
column_names = features_open.columns.tolist()
print(column_names)
# Out:
# ['pack_size', 'timestamp', 'cumulative_sizes', 'burst', 'num_pack', 'med']

# %%
import ast
import numpy as np

# %%
constant_o = pd.DataFrame()
constant_c = pd.DataFrame()

# %%
std_dev_out_c = []
std_dev_in_c= []
std_dev_out_o = []
std_dev_in_o= []

avg_out_c = []
avg_out_o = []

flag_close=False

avg_in_c = []
avg_in_o = []

for idx, i in enumerate(features_open['burst']) :
    list = ast.literal_eval(i)
    tmp_o=[]
    tmp_i =[]
    if(y_mul['y'][idx]==-1) :
        flag_close=True
    for j in list:
        if(j==0):
            break
        elif j < 0: #들어오는
            tmp_i.append(j)
        else : #나가는
            tmp_o.append(j)
    std_dev_out_o.append(np.std(np.abs(tmp_o)))
    std_dev_in_o.append(np.std(np.abs(tmp_i)))
    avg_out_o.append(np.mean(tmp_o))
    avg_in_o.append(np.mean(tmp_i))
    if(flag_close==False):
        std_dev_out_c.append(np.std(np.abs(tmp_o)))
        std_dev_in_c.append(np.std(np.abs(tmp_i)))
        avg_out_c.append(np.mean(tmp_o))
        avg_in_c.append(np.mean(tmp_i))

# %%
flag_close=False

in_pack_num_c = []
out_pack_num_c = []
in_pack_num_o = []
out_pack_num_o = []

in_pack_ratio_c = []
out_pack_ratio_c = []
in_pack_ratio_o = []
out_pack_ratio_o = []

# 10
total_pack_num_c=[]
total_pack_num_o=[]
#6
total_pack_sum_c=[]
total_pack_sum_o=[]
# 8-1 
in_pack_sum_c=[]
in_pack_sum_o=[]
# 8-2
out_pack_sum_c=[]
out_pack_sum_o=[]

for idx, i in enumerate(features_open['pack_size']) :
    list = ast.literal_eval(i)
    if(y_mul['y'][idx]==-1) :
        flag_close=True
    cnt=0
    in_c=0
    out_c=0
    in_s=0
    out_s=0
    for j in list :
        if(j==0) :
            break
        else :
            cnt+=1
            if(j<0) :
                in_s+=j
                in_c+=1
            else :
                out_s +=j
                out_c +=1
    if(flag_close==False) :
        total_pack_num_c.append(cnt)
        in_pack_sum_c.append(in_s)
        out_pack_sum_c.append(out_s)
        total_pack_sum_c.append(in_s+out_s)
        in_pack_num_c.append(in_c)
        out_pack_num_c.append(out_c)
        in_pack_ratio_c.append(in_c/cnt)
        out_pack_ratio_c.append(out_c/cnt)
    total_pack_num_o.append(cnt)
    in_pack_sum_o.append(in_s)
    out_pack_sum_o.append(out_s)
    total_pack_sum_o.append(in_s+out_s)
    in_pack_num_o.append(in_c)
    out_pack_num_o.append(out_c)
    in_pack_ratio_o.append(in_c/cnt)
    out_pack_ratio_o.append(out_c/cnt)

# %%
#9
total_sum_pack_per_sec_c = []
total_sum_pack_per_sec_o = []

total_num_pack_per_sec_c = []
total_num_pack_per_sec_o = []

flag_close=False

for idx, i in enumerate(features_open['timestamp']) :
    list = ast.literal_eval(i)
    if(y_mul['y'][idx]==-1) :
        flag_close=True
    time_sum= sum(list)
    total_sum_pack_per_sec_o.append(total_pack_sum_o[idx]/time_sum)
    total_num_pack_per_sec_o.append(total_pack_num_o[idx]/time_sum)
    if(flag_close==False) :
        total_sum_pack_per_sec_c.append(total_pack_sum_c[idx]/time_sum)
        total_num_pack_per_sec_c.append(total_pack_num_c[idx]/time_sum)

# %%
# med 를 이용
#med의 합
sum_med_c=[]
sum_med_o=[]

#med 표준편차
std_dev_med_c = []
std_dev_med_o = []

#med 평균
avg_med_c = []
avg_med_o = []

#burst * med , burst*med avg , burst * med std
sum_burst_med_c = []
sum_burst_med_o = []

avg_burst_med_c = []
avg_burst_med_o = []

std_burst_med_c = []
std_burst_med_o = []

flag_close=False

for idx, i in enumerate(features_open['med']) :
    tmp = []
    burst_med = []
    med = ast.literal_eval(i)
    burst = ast.literal_eval(features_open['burst'][idx])
    burst = [x for x in burst if x != 0]
    med = [x for x in med if x != 0]
    if(y_mul['y'][idx]==-1) :
        flag_close=True
    for it, j in enumerate (med) :
        tmp.append(j)
        burst_med.append(j*it)
            
    sum_med_o.append(sum(tmp))
    std_dev_med_o.append(np.std(np.abs(tmp)))
    avg_med_o.append(np.mean(tmp))
    sum_burst_med_o.append(sum(burst_med))
    avg_burst_med_o.append((np.mean(burst_med)))
    std_burst_med_o.append(np.std(np.abs(burst_med)))
    if (flag_close==False):
        sum_med_c.append(sum(tmp))
        std_dev_med_c.append(np.std(np.abs(tmp)))
        avg_med_c.append(np.mean(tmp))                  
        sum_burst_med_c.append(sum(burst_med))
        avg_burst_med_c.append((np.mean(burst_med)))
        std_burst_med_c.append(np.std(np.abs(burst_med)))

# %%
#19, 20 처음 30개 incoming, outgoing 갯수, 합 비율
in_num_30_c = []
in_num_30_o = []
out_num_30_c = []
out_num_30_o = []

in_sum_30_c = []
in_sum_30_o = []
out_sum_30_c = []
out_sum_30_o = []

flag_close =False

for idx, i in enumerate(features_open['pack_size']) :
    list = ast.literal_eval(i)
    if(y_mul['y'][idx]==-1) :
        flag_close=True
    in_c=0
    out_c=0
    in_s=0
    out_s=0
    for it,j in enumerate(list) :
        if(j==0 or it>30) :
            break
        else :
            if(j<0) :
                in_c+=1
                in_s+=j
            else :
                out_c +=1
                out_s+=j
    if(flag_close==False) :
        in_num_30_c.append(in_c/30)
        out_num_30_c.append(out_c/30)
        in_sum_30_c.append(in_s/(out_s+in_s))
        out_sum_30_c.append(out_s/(out_s+in_s))
    in_num_30_o.append(in_c/30)
    out_num_30_o.append(out_c/30)
    in_sum_30_o.append(in_s/(out_s+in_s))
    out_sum_30_o.append(out_s/(out_s+in_s))

# %%
constant_o['std_dev_out_o'] = std_dev_out_o
constant_o['std_dev_in_o'] = std_dev_in_o
constant_o['avg_out_o'] = avg_out_o
constant_o['avg_in_o'] = avg_in_o
constant_c['std_dev_out_c'] = std_dev_out_c
constant_c['std_dev_in_c'] = std_dev_in_c
constant_c['avg_out_c'] = avg_out_c
constant_c['avg_in_c'] = avg_in_c

constant_o['in_pack_num_o'] = in_pack_num_o
constant_o['out_pack_num_o'] = out_pack_num_o
constant_o['in_pack_ratio_o'] = in_pack_ratio_o
constant_o['out_pack_ratio_o'] = out_pack_ratio_o
constant_o['total_pack_num_o'] = total_pack_num_o
constant_o['total_pack_sum_o'] = total_pack_sum_o
constant_o['in_pack_sum_o'] = in_pack_sum_o
constant_o['out_pack_sum_o'] = out_pack_sum_o


constant_c['in_pack_num_c'] = in_pack_num_c
constant_c['out_pack_num_c'] = out_pack_num_c
constant_c['in_pack_ratio_c'] = in_pack_ratio_c
constant_c['out_pack_ratio_c'] = out_pack_ratio_c
constant_c['total_pack_num_c'] = total_pack_num_c
constant_c['total_pack_sum_c'] = total_pack_sum_c
constant_c['in_pack_sum_c'] = in_pack_sum_c
constant_c['out_pack_sum_c'] = out_pack_sum_c

constant_o['total_sum_pack_per_sec_o'] = total_sum_pack_per_sec_o
constant_o['total_num_pack_per_sec_o'] = total_num_pack_per_sec_o


constant_c['total_sum_pack_per_sec_c'] = total_sum_pack_per_sec_c
constant_c['total_num_pack_per_sec_c'] = total_num_pack_per_sec_c

constant_o['sum_med_o'] = sum_med_o
constant_o['std_dev_med_o'] = std_dev_med_o
constant_o['avg_med_o'] = avg_med_o
constant_o['sum_burst_med_o'] = sum_burst_med_o
constant_o['avg_burst_med_o'] = avg_burst_med_o
constant_o['std_burst_med_o'] = std_burst_med_o


constant_c['sum_med_c'] = sum_med_c
constant_c['std_dev_med_c'] = std_dev_med_c
constant_c['avg_med_c'] = avg_med_c
constant_c['sum_burst_med_c'] = sum_burst_med_c
constant_c['avg_burst_med_c'] = avg_burst_med_c
constant_c['std_burst_med_c'] = std_burst_med_c


constant_o['in_num_30_o'] = in_num_30_o
constant_o['out_num_30_o'] = out_num_30_o
constant_o['in_sum_30_o'] = in_sum_30_o
constant_o['out_sum_30_o'] = out_sum_30_o

constant_c['in_num_30_c'] = in_num_30_c
constant_c['out_num_30_c'] = out_num_30_c
constant_c['in_sum_30_c'] = in_sum_30_c
constant_c['out_sum_30_c'] = out_sum_30_c

print(constant_o, constant_c)


print(constant_o, constant_c)

column_names = constant_o.columns.tolist()
print("open : " , len(constant_o), column_names)

column_names = constant_c.columns.tolist()
print("close : " , len(constant_c), column_names)

print(constant_o, constant_c)
constant_c.head()
# Out:
#        std_dev_out_o  std_dev_in_o     avg_out_o    avg_in_o  out_pack_sum_o  \
# 0        8804.074271    583.467122  -8533.333333  794.256410         -665600
# 1        6234.214393    577.669930  -4771.404255  871.489362         -224256
# 2        8491.051222    501.068907  -8353.684211  794.947368         -634880
# 3        8833.261359    435.764340  -8473.600000  780.800000         -677888
# 4        8199.241792    452.094186  -8366.987342  745.316456         -660992
# ...              ...           ...           ...         ...             ...
# 23995   10016.514200    486.005087 -11925.126214  691.824390        -2456576
# 23996    7999.422252    889.429842  -7393.882353  945.230769        -1256960
# 23997    8426.315381    546.667768  -9069.248408  746.802548        -1423872
# 23998    9512.596927    892.282354 -12488.481928  702.259819        -4146176
# 23999    9414.854726    877.911288  -9724.419580  898.685315        -1390592
#
#        in_pack_num_o  out_pack_num_o  in_pack_ratio_o  out_pack_ratio_o  \
# 0                121            1300         0.085151          0.914849
# 1                 80             438         0.154440          0.845560
# 2                118            1240         0.086892          0.913108
# 3                122            1324         0.084371          0.915629
# 4                115            1291         0.081792          0.918208
# ...              ...             ...              ...               ...
# 23995            277            4798         0.054581          0.945419
# 23996            312            2455         0.112757          0.887243
# 23997            229            2781         0.076080          0.923920
# 23998            454            8098         0.053087          0.946913
# 23999            251            2716         0.084597          0.915403
#
#        total_pack_num_o  ...  avg_med_o  sum_burst_med_o  avg_burst_med_o  \
# 0                  1421  ...   4.457244        66290.670       424.940192
# 1                   518  ...   4.123138        21951.425       233.525798
# 2                  1358  ...   5.594408        76706.350       504.647039
# 3                  1446  ...   6.349125       100186.490       626.165563
# 4                  1406  ...   4.937057        75665.070       478.892848
# ...                 ...  ...        ...              ...              ...
# 23995              5075  ...   7.441655       723129.065      1759.438114
# 23996              2767  ...  10.459336       748706.785      2208.574587
# 23997              3010  ...   7.435159       425089.400      1353.787898
# 23998              8552  ...  10.977262      2778656.145      4191.034910
# 23999              2967  ...   5.812622       291414.875      1018.933129
#
#        std_burst_med_o  in_num_30_o  out_num_30_o  in_sum_30_o  out_sum_30_o  \
# 0           364.215624     0.300000      0.733333    -0.692308      1.692308
# 1           182.192475     0.300000      0.733333    -0.692308      1.692308
# 2           400.371440     0.266667      0.766667    -0.533333      1.533333
# 3           550.273491     0.300000      0.733333    -0.692308      1.692308
# 4           419.811106     0.300000      0.733333    -0.692308      1.692308
# ...                ...          ...           ...          ...           ...
# 23995      1439.558660     0.466667      0.566667    -4.666667      5.666667
# 23996      2073.836677     0.400000      0.633333    -1.714286      2.714286
# 23997      1072.996971     0.366667      0.666667    -1.222222      2.222222
# 23998      3131.353699     0.333333      0.700000    -0.909091      1.909091
# 23999      1338.230949     0.300000      0.733333    -0.692308      1.692308
#
#        total_sum_pack_per_sec_o  total_num_pack_per_sec_o
# 0                    -98.431355                  0.231709
# 1                    -76.727559                  0.216834
# 2                    -77.067676                  0.182184
# 3                    -70.987172                  0.166791
# 4                    -91.137815                  0.212817
# ...                         ...                       ...
# 23995                -62.435892                  0.136888
# 23996                -37.071966                  0.093489
# 23997                -58.067842                  0.133768
# 23998                -39.430978                  0.086162
# 23999                -81.058081                  0.190558
#
# [24000 rows x 24 columns]        std_dev_out_c  std_dev_in_c     avg_out_c    avg_in_c  in_pack_num_c  \
# 0        8804.074271    583.467122  -8533.333333  794.256410            121
# 1        6234.214393    577.669930  -4771.404255  871.489362             80
# 2        8491.051222    501.068907  -8353.684211  794.947368            118
# 3        8833.261359    435.764340  -8473.600000  780.800000            122
# 4        8199.241792    452.094186  -8366.987342  745.316456            115
# ...              ...           ...           ...         ...            ...
# 18995    9641.269125    951.333508 -12099.946381  849.672922            619
# 18996    9900.870915   1001.030213 -13300.685083  782.891967            552
# 18997    9648.251495    855.330648 -12935.245283  799.051213            579
# 18998    9507.187446    877.050879 -11618.751843  870.147783            690
# 18999    9420.849954   1107.819405 -11561.615764  956.997531            757
#
#        out_pack_num_c  in_pack_ratio_c  out_pack_ratio_c  total_pack_num_c  \
# 0                1300         0.085151          0.914849              1421
# 1                 438         0.154440          0.845560               518
# 2                1240         0.086892          0.913108              1358
# 3                1324         0.084371          0.915629              1446
# 4                1291         0.081792          0.918208              1406
# ...               ...              ...               ...               ...
# 18995            8815         0.065614          0.934386              9434
# 18996            9404         0.055444          0.944556              9956
# 18997            9373         0.058179          0.941821              9952
# 18998            9236         0.069514          0.930486              9926
# 18999            9168         0.076272          0.923728              9925
#
#        total_pack_sum_c  ...  avg_med_c  sum_burst_med_c  avg_burst_med_c  \
# 0               -603648  ...   4.457244        66290.670       424.940192
# 1               -183296  ...   4.123138        21951.425       233.525798
# 2               -574464  ...   5.594408        76706.350       504.647039
# 3               -615424  ...   6.349125       100186.490       626.165563
# 4               -602112  ...   4.937057        75665.070       478.892848
# ...                 ...  ...        ...              ...              ...
# 18995          -4196352  ...   8.953760      3030917.510      4062.892105
# 18996          -4532224  ...   8.882261      2730516.220      3776.647607
# 18997          -4502528  ...   8.499218      2762759.075      3723.394980
# 18998          -4375552  ...  14.252811      5290752.410      6507.690541
# 18999          -4306432  ...   7.684871      2993961.730      3691.691406
#
#        std_burst_med_c  in_num_30_c  out_num_30_c  in_sum_30_c  out_sum_30_c  \
# 0           364.215624     0.300000      0.733333    -0.692308      1.692308
# 1           182.192475     0.300000      0.733333    -0.692308      1.692308
# 2           400.371440     0.266667      0.766667    -0.533333      1.533333
# 3           550.273491     0.300000      0.733333    -0.692308      1.692308
# 4           419.811106     0.300000      0.733333    -0.692308      1.692308
# ...                ...          ...           ...          ...           ...
# 18995      3643.529147     0.233333      0.800000    -0.411765      1.411765
# 18996      2980.815798     0.233333      0.800000    -0.411765      1.411765
# 18997      2959.881964     0.266667      0.766667    -0.533333      1.533333
# 18998      4509.900210     0.233333      0.800000    -0.411765      1.411765
# 18999      2865.325266     0.233333      0.800000    -0.411765      1.411765
#
#        total_sum_pack_per_sec_c  total_num_pack_per_sec_c
# 0                    -98.431355                  0.231709
# 1                    -76.727559                  0.216834
# 2                    -77.067676                  0.182184
# 3                    -70.987172                  0.166791
# 4                    -91.137815                  0.212817
# ...                         ...                       ...
# 18995                -53.225417                  0.119658
# 18996                -51.446358                  0.113013
# 18997                -53.953144                  0.119253
# 18998                -31.471112                  0.071393
# 18999                -58.576224                  0.135000
#
# [19000 rows x 24 columns]
#        std_dev_out_o  std_dev_in_o     avg_out_o    avg_in_o  out_pack_sum_o  \
# 0        8804.074271    583.467122  -8533.333333  794.256410         -665600
# 1        6234.214393    577.669930  -4771.404255  871.489362         -224256
# 2        8491.051222    501.068907  -8353.684211  794.947368         -634880
# 3        8833.261359    435.764340  -8473.600000  780.800000         -677888
# 4        8199.241792    452.094186  -8366.987342  745.316456         -660992
# ...              ...           ...           ...         ...             ...
# 23995   10016.514200    486.005087 -11925.126214  691.824390        -2456576
# 23996    7999.422252    889.429842  -7393.882353  945.230769        -1256960
# 23997    8426.315381    546.667768  -9069.248408  746.802548        -1423872
# 23998    9512.596927    892.282354 -12488.481928  702.259819        -4146176
# 23999    9414.854726    877.911288  -9724.419580  898.685315        -1390592
#
#        in_pack_num_o  out_pack_num_o  in_pack_ratio_o  out_pack_ratio_o  \
# 0                121            1300         0.085151          0.914849
# 1                 80             438         0.154440          0.845560
# 2                118            1240         0.086892          0.913108
# 3                122            1324         0.084371          0.915629
# 4                115            1291         0.081792          0.918208
# ...              ...             ...              ...               ...
# 23995            277            4798         0.054581          0.945419
# 23996            312            2455         0.112757          0.887243
# 23997            229            2781         0.076080          0.923920
# 23998            454            8098         0.053087          0.946913
# 23999            251            2716         0.084597          0.915403
#
#        total_pack_num_o  ...  avg_med_o  sum_burst_med_o  avg_burst_med_o  \
# 0                  1421  ...   4.457244        66290.670       424.940192
# 1                   518  ...   4.123138        21951.425       233.525798
# 2                  1358  ...   5.594408        76706.350       504.647039
# 3                  1446  ...   6.349125       100186.490       626.165563
# 4                  1406  ...   4.937057        75665.070       478.892848
# ...                 ...  ...        ...              ...              ...
# 23995              5075  ...   7.441655       723129.065      1759.438114
# 23996              2767  ...  10.459336       748706.785      2208.574587
# 23997              3010  ...   7.435159       425089.400      1353.787898
# 23998              8552  ...  10.977262      2778656.145      4191.034910
# 23999              2967  ...   5.812622       291414.875      1018.933129
#
#        std_burst_med_o  in_num_30_o  out_num_30_o  in_sum_30_o  out_sum_30_o  \
# 0           364.215624     0.300000      0.733333    -0.692308      1.692308
# 1           182.192475     0.300000      0.733333    -0.692308      1.692308
# 2           400.371440     0.266667      0.766667    -0.533333      1.533333
# 3           550.273491     0.300000      0.733333    -0.692308      1.692308
# 4           419.811106     0.300000      0.733333    -0.692308      1.692308
# ...                ...          ...           ...          ...           ...
# 23995      1439.558660     0.466667      0.566667    -4.666667      5.666667
# 23996      2073.836677     0.400000      0.633333    -1.714286      2.714286
# 23997      1072.996971     0.366667      0.666667    -1.222222      2.222222
# 23998      3131.353699     0.333333      0.700000    -0.909091      1.909091
# 23999      1338.230949     0.300000      0.733333    -0.692308      1.692308
#
#        total_sum_pack_per_sec_o  total_num_pack_per_sec_o
# 0                    -98.431355                  0.231709
# 1                    -76.727559                  0.216834
# 2                    -77.067676                  0.182184
# 3                    -70.987172                  0.166791
# 4                    -91.137815                  0.212817
# ...                         ...                       ...
# 23995                -62.435892                  0.136888
# 23996                -37.071966                  0.093489
# 23997                -58.067842                  0.133768
# 23998                -39.430978                  0.086162
# 23999                -81.058081                  0.190558
#
# [24000 rows x 24 columns]        std_dev_out_c  std_dev_in_c     avg_out_c    avg_in_c  in_pack_num_c  \
# 0        8804.074271    583.467122  -8533.333333  794.256410            121
# 1        6234.214393    577.669930  -4771.404255  871.489362             80
# 2        8491.051222    501.068907  -8353.684211  794.947368            118
# 3        8833.261359    435.764340  -8473.600000  780.800000            122
# 4        8199.241792    452.094186  -8366.987342  745.316456            115
# ...              ...           ...           ...         ...            ...
# 18995    9641.269125    951.333508 -12099.946381  849.672922            619
# 18996    9900.870915   1001.030213 -13300.685083  782.891967            552
# 18997    9648.251495    855.330648 -12935.245283  799.051213            579
# 18998    9507.187446    877.050879 -11618.751843  870.147783            690
# 18999    9420.849954   1107.819405 -11561.615764  956.997531            757
#
#        out_pack_num_c  in_pack_ratio_c  out_pack_ratio_c  total_pack_num_c  \
# 0                1300         0.085151          0.914849              1421
# 1                 438         0.154440          0.845560               518
# 2                1240         0.086892          0.913108              1358
# 3                1324         0.084371          0.915629              1446
# 4                1291         0.081792          0.918208              1406
# ...               ...              ...               ...               ...
# 18995            8815         0.065614          0.934386              9434
# 18996            9404         0.055444          0.944556              9956
# 18997            9373         0.058179          0.941821              9952
# 18998            9236         0.069514          0.930486              9926
# 18999            9168         0.076272          0.923728              9925
#
#        total_pack_sum_c  ...  avg_med_c  sum_burst_med_c  avg_burst_med_c  \
# 0               -603648  ...   4.457244        66290.670       424.940192
# 1               -183296  ...   4.123138        21951.425       233.525798
# 2               -574464  ...   5.594408        76706.350       504.647039
# 3               -615424  ...   6.349125       100186.490       626.165563
# 4               -602112  ...   4.937057        75665.070       478.892848
# ...                 ...  ...        ...              ...              ...
# 18995          -4196352  ...   8.953760      3030917.510      4062.892105
# 18996          -4532224  ...   8.882261      2730516.220      3776.647607
# 18997          -4502528  ...   8.499218      2762759.075      3723.394980
# 18998          -4375552  ...  14.252811      5290752.410      6507.690541
# 18999          -4306432  ...   7.684871      2993961.730      3691.691406
#
#        std_burst_med_c  in_num_30_c  out_num_30_c  in_sum_30_c  out_sum_30_c  \
# 0           364.215624     0.300000      0.733333    -0.692308      1.692308
# 1           182.192475     0.300000      0.733333    -0.692308      1.692308
# 2           400.371440     0.266667      0.766667    -0.533333      1.533333
# 3           550.273491     0.300000      0.733333    -0.692308      1.692308
# 4           419.811106     0.300000      0.733333    -0.692308      1.692308
# ...                ...          ...           ...          ...           ...
# 18995      3643.529147     0.233333      0.800000    -0.411765      1.411765
# 18996      2980.815798     0.233333      0.800000    -0.411765      1.411765
# 18997      2959.881964     0.266667      0.766667    -0.533333      1.533333
# 18998      4509.900210     0.233333      0.800000    -0.411765      1.411765
# 18999      2865.325266     0.233333      0.800000    -0.411765      1.411765
#
#        total_sum_pack_per_sec_c  total_num_pack_per_sec_c
# 0                    -98.431355                  0.231709
# 1                    -76.727559                  0.216834
# 2                    -77.067676                  0.182184
# 3                    -70.987172                  0.166791
# 4                    -91.137815                  0.212817
# ...                         ...                       ...
# 18995                -53.225417                  0.119658
# 18996                -51.446358                  0.113013
# 18997                -53.953144                  0.119253
# 18998                -31.471112                  0.071393
# 18999                -58.576224                  0.135000
#
# [19000 rows x 24 columns]
# open :  24000 ['std_dev_out_o', 'std_dev_in_o', 'avg_out_o', 'avg_in_o', 'out_pack_sum_o', 'in_pack_num_o', 'out_pack_num_o', 'in_pack_ratio_o', 'out_pack_ratio_o', 'total_pack_num_o', 'total_pack_sum_o', 'in_pack_sum_o', 'sum_med_o', 'std_dev_med_o', 'avg_med_o', 'sum_burst_med_o', 'avg_burst_med_o', 'std_burst_med_o', 'in_num_30_o', 'out_num_30_o', 'in_sum_30_o', 'out_sum_30_o', 'total_sum_pack_per_sec_o', 'total_num_pack_per_sec_o']
# close :  19000 ['std_dev_out_c', 'std_dev_in_c', 'avg_out_c', 'avg_in_c', 'in_pack_num_c', 'out_pack_num_c', 'in_pack_ratio_c', 'out_pack_ratio_c', 'total_pack_num_c', 'total_pack_sum_c', 'in_pack_sum_c', 'out_pack_sum_c', 'sum_med_c', 'std_dev_med_c', 'avg_med_c', 'sum_burst_med_c', 'avg_burst_med_c', 'std_burst_med_c', 'in_num_30_c', 'out_num_30_c', 'in_sum_30_c', 'out_sum_30_c', 'total_sum_pack_per_sec_c', 'total_num_pack_per_sec_c']
#        std_dev_out_o  std_dev_in_o     avg_out_o    avg_in_o  out_pack_sum_o  \
# 0        8804.074271    583.467122  -8533.333333  794.256410         -665600
# 1        6234.214393    577.669930  -4771.404255  871.489362         -224256
# 2        8491.051222    501.068907  -8353.684211  794.947368         -634880
# 3        8833.261359    435.764340  -8473.600000  780.800000         -677888
# 4        8199.241792    452.094186  -8366.987342  745.316456         -660992
# ...              ...           ...           ...         ...             ...
# 23995   10016.514200    486.005087 -11925.126214  691.824390        -2456576
# 23996    7999.422252    889.429842  -7393.882353  945.230769        -1256960
# 23997    8426.315381    546.667768  -9069.248408  746.802548        -1423872
# 23998    9512.596927    892.282354 -12488.481928  702.259819        -4146176
# 23999    9414.854726    877.911288  -9724.419580  898.685315        -1390592
#
#        in_pack_num_o  out_pack_num_o  in_pack_ratio_o  out_pack_ratio_o  \
# 0                121            1300         0.085151          0.914849
# 1                 80             438         0.154440          0.845560
# 2                118            1240         0.086892          0.913108
# 3                122            1324         0.084371          0.915629
# 4                115            1291         0.081792          0.918208
# ...              ...             ...              ...               ...
# 23995            277            4798         0.054581          0.945419
# 23996            312            2455         0.112757          0.887243
# 23997            229            2781         0.076080          0.923920
# 23998            454            8098         0.053087          0.946913
# 23999            251            2716         0.084597          0.915403
#
#        total_pack_num_o  ...  avg_med_o  sum_burst_med_o  avg_burst_med_o  \
# 0                  1421  ...   4.457244        66290.670       424.940192
# 1                   518  ...   4.123138        21951.425       233.525798
# 2                  1358  ...   5.594408        76706.350       504.647039
# 3                  1446  ...   6.349125       100186.490       626.165563
# 4                  1406  ...   4.937057        75665.070       478.892848
# ...                 ...  ...        ...              ...              ...
# 23995              5075  ...   7.441655       723129.065      1759.438114
# 23996              2767  ...  10.459336       748706.785      2208.574587
# 23997              3010  ...   7.435159       425089.400      1353.787898
# 23998              8552  ...  10.977262      2778656.145      4191.034910
# 23999              2967  ...   5.812622       291414.875      1018.933129
#
#        std_burst_med_o  in_num_30_o  out_num_30_o  in_sum_30_o  out_sum_30_o  \
# 0           364.215624     0.300000      0.733333    -0.692308      1.692308
# 1           182.192475     0.300000      0.733333    -0.692308      1.692308
# 2           400.371440     0.266667      0.766667    -0.533333      1.533333
# 3           550.273491     0.300000      0.733333    -0.692308      1.692308
# 4           419.811106     0.300000      0.733333    -0.692308      1.692308
# ...                ...          ...           ...          ...           ...
# 23995      1439.558660     0.466667      0.566667    -4.666667      5.666667
# 23996      2073.836677     0.400000      0.633333    -1.714286      2.714286
# 23997      1072.996971     0.366667      0.666667    -1.222222      2.222222
# 23998      3131.353699     0.333333      0.700000    -0.909091      1.909091
# 23999      1338.230949     0.300000      0.733333    -0.692308      1.692308
#
#        total_sum_pack_per_sec_o  total_num_pack_per_sec_o
# 0                    -98.431355                  0.231709
# 1                    -76.727559                  0.216834
# 2                    -77.067676                  0.182184
# 3                    -70.987172                  0.166791
# 4                    -91.137815                  0.212817
# ...                         ...                       ...
# 23995                -62.435892                  0.136888
# 23996                -37.071966                  0.093489
# 23997                -58.067842                  0.133768
# 23998                -39.430978                  0.086162
# 23999                -81.058081                  0.190558
#
# [24000 rows x 24 columns]        std_dev_out_c  std_dev_in_c     avg_out_c    avg_in_c  in_pack_num_c  \
# 0        8804.074271    583.467122  -8533.333333  794.256410            121
# 1        6234.214393    577.669930  -4771.404255  871.489362             80
# 2        8491.051222    501.068907  -8353.684211  794.947368            118
# 3        8833.261359    435.764340  -8473.600000  780.800000            122
# 4        8199.241792    452.094186  -8366.987342  745.316456            115
# ...              ...           ...           ...         ...            ...
# 18995    9641.269125    951.333508 -12099.946381  849.672922            619
# 18996    9900.870915   1001.030213 -13300.685083  782.891967            552
# 18997    9648.251495    855.330648 -12935.245283  799.051213            579
# 18998    9507.187446    877.050879 -11618.751843  870.147783            690
# 18999    9420.849954   1107.819405 -11561.615764  956.997531            757
#
#        out_pack_num_c  in_pack_ratio_c  out_pack_ratio_c  total_pack_num_c  \
# 0                1300         0.085151          0.914849              1421
# 1                 438         0.154440          0.845560               518
# 2                1240         0.086892          0.913108              1358
# 3                1324         0.084371          0.915629              1446
# 4                1291         0.081792          0.918208              1406
# ...               ...              ...               ...               ...
# 18995            8815         0.065614          0.934386              9434
# 18996            9404         0.055444          0.944556              9956
# 18997            9373         0.058179          0.941821              9952
# 18998            9236         0.069514          0.930486              9926
# 18999            9168         0.076272          0.923728              9925
#
#        total_pack_sum_c  ...  avg_med_c  sum_burst_med_c  avg_burst_med_c  \
# 0               -603648  ...   4.457244        66290.670       424.940192
# 1               -183296  ...   4.123138        21951.425       233.525798
# 2               -574464  ...   5.594408        76706.350       504.647039
# 3               -615424  ...   6.349125       100186.490       626.165563
# 4               -602112  ...   4.937057        75665.070       478.892848
# ...                 ...  ...        ...              ...              ...
# 18995          -4196352  ...   8.953760      3030917.510      4062.892105
# 18996          -4532224  ...   8.882261      2730516.220      3776.647607
# 18997          -4502528  ...   8.499218      2762759.075      3723.394980
# 18998          -4375552  ...  14.252811      5290752.410      6507.690541
# 18999          -4306432  ...   7.684871      2993961.730      3691.691406
#
#        std_burst_med_c  in_num_30_c  out_num_30_c  in_sum_30_c  out_sum_30_c  \
# 0           364.215624     0.300000      0.733333    -0.692308      1.692308
# 1           182.192475     0.300000      0.733333    -0.692308      1.692308
# 2           400.371440     0.266667      0.766667    -0.533333      1.533333
# 3           550.273491     0.300000      0.733333    -0.692308      1.692308
# 4           419.811106     0.300000      0.733333    -0.692308      1.692308
# ...                ...          ...           ...          ...           ...
# 18995      3643.529147     0.233333      0.800000    -0.411765      1.411765
# 18996      2980.815798     0.233333      0.800000    -0.411765      1.411765
# 18997      2959.881964     0.266667      0.766667    -0.533333      1.533333
# 18998      4509.900210     0.233333      0.800000    -0.411765      1.411765
# 18999      2865.325266     0.233333      0.800000    -0.411765      1.411765
#
#        total_sum_pack_per_sec_c  total_num_pack_per_sec_c
# 0                    -98.431355                  0.231709
# 1                    -76.727559                  0.216834
# 2                    -77.067676                  0.182184
# 3                    -70.987172                  0.166791
# 4                    -91.137815                  0.212817
# ...                         ...                       ...
# 18995                -53.225417                  0.119658
# 18996                -51.446358                  0.113013
# 18997                -53.953144                  0.119253
# 18998                -31.471112                  0.071393
# 18999                -58.576224                  0.135000
#
# [19000 rows x 24 columns]
#    std_dev_out_c  std_dev_in_c    avg_out_c    avg_in_c  in_pack_num_c  \
# 0    8804.074271    583.467122 -8533.333333  794.256410            121
# 1    6234.214393    577.669930 -4771.404255  871.489362             80
# 2    8491.051222    501.068907 -8353.684211  794.947368            118
# 3    8833.261359    435.764340 -8473.600000  780.800000            122
# 4    8199.241792    452.094186 -8366.987342  745.316456            115
#
#    out_pack_num_c  in_pack_ratio_c  out_pack_ratio_c  total_pack_num_c  \
# 0            1300         0.085151          0.914849              1421
# 1             438         0.154440          0.845560               518
# 2            1240         0.086892          0.913108              1358
# 3            1324         0.084371          0.915629              1446
# 4            1291         0.081792          0.918208              1406
#
#    total_pack_sum_c  ...  avg_med_c  sum_burst_med_c  avg_burst_med_c  \
# 0           -603648  ...   4.457244        66290.670       424.940192
# 1           -183296  ...   4.123138        21951.425       233.525798
# 2           -574464  ...   5.594408        76706.350       504.647039
# 3           -615424  ...   6.349125       100186.490       626.165563
# 4           -602112  ...   4.937057        75665.070       478.892848
#
#    std_burst_med_c  in_num_30_c  out_num_30_c  in_sum_30_c  out_sum_30_c  \
# 0       364.215624     0.300000      0.733333    -0.692308      1.692308
# 1       182.192475     0.300000      0.733333    -0.692308      1.692308
# 2       400.371440     0.266667      0.766667    -0.533333      1.533333
# 3       550.273491     0.300000      0.733333    -0.692308      1.692308
# 4       419.811106     0.300000      0.733333    -0.692308      1.692308
#
#    total_sum_pack_per_sec_c  total_num_pack_per_sec_c
# 0                -98.431355                  0.231709
# 1                -76.727559                  0.216834
# 2                -77.067676                  0.182184
# 3                -70.987172                  0.166791
# 4                -91.137815                  0.212817
#
# [5 rows x 24 columns]

# %%
#bound
#from sklearn.preprocessing import MinMaxScaler



# MinMaxScaler를 각 열에 따로 적용하여 기존 데이터프레임에 넣어줌
#scaler = MinMaxScaler()

for i, column in enumerate(constant_c.columns):
        #column_data = constant_c[column].values.reshape(-1, 1)  # 열 벡터로 변환
        #constant_c[column] = scaler.fit_transform(column_data)  # 정규화된 값으로 열 대체
        #column_data = constant_c[column].values.reshape(-1, 1)  # 열 벡터로 변환
        constant_c[column] = np.round(constant_c[column], 3)  # 소수점 셋째 자리까지 반올림하여 저장

for i, column in enumerate(constant_o.columns):
        #column_data = constant_o[column].values.reshape(-1, 1)  # 열 벡터로 변환
        #constant_o[column] = scaler.fit_transform(column_data)  # 정규화된 값으로 열 대체
        #column_data = constant_o[column].values.reshape(-1, 1)  # 열 벡터로 변환
        constant_o[column] = np.round(constant_o[column], 3)  # 소수점 셋째 자리까지 반올림하여 저장

# %%
constant_c.head()
# Out:
#    std_dev_out_c  std_dev_in_c  avg_out_c  avg_in_c  in_pack_num_c  \
# 0         0.4936        0.0225     0.6810    0.0494         0.0272
# 1         0.3388        0.0223     0.8419    0.0631         0.0175
# 2         0.4748        0.0192     0.6887    0.0496         0.0264
# 3         0.4954        0.0165     0.6836    0.0471         0.0274
# 4         0.4572        0.0172     0.6881    0.0408         0.0257
#
#    out_pack_num_c  in_pack_ratio_c  out_pack_ratio_c  total_pack_num_c  \
# 0          0.1318           0.1153            0.8847            0.1379
# 1          0.0427           0.2600            0.7400            0.0471
# 2          0.1256           0.1195            0.8805            0.1315
# 3          0.1343           0.1132            0.8868            0.1404
# 4          0.1309           0.1090            0.8910            0.1364
#
#    total_pack_sum_c  ...  avg_med_c  sum_burst_med_c  avg_burst_med_c  \
# 0            0.8745  ...     0.0740           0.0027           0.0186
# 1            0.9618  ...     0.0673           0.0009           0.0100
# 2            0.8806  ...     0.0969           0.0031           0.0221
# 3            0.8721  ...     0.1121           0.0041           0.0275
# 4            0.8748  ...     0.0837           0.0031           0.0210
#
#    std_burst_med_c  in_num_30_c  out_num_30_c  in_sum_30_c  out_sum_30_c  \
# 0           0.0190       0.3576        0.6424       0.4615        0.5385
# 1           0.0093       0.3576        0.6424       0.4615        0.5385
# 2           0.0209       0.2869        0.7152       0.4667        0.5333
# 3           0.0289       0.3576        0.6424       0.4615        0.5385
# 4           0.0219       0.3576        0.6424       0.4615        0.5385
#
#    total_sum_pack_per_sec_c  total_num_pack_per_sec_c
# 0                    0.7140                    0.2240
# 1                    0.7768                    0.2082
# 2                    0.7758                    0.1714
# 3                    0.7934                    0.1556
# 4                    0.7351                    0.2040
#
# [5 rows x 24 columns]

# %%
constant_o.head()
# Out:
#    std_dev_out_o  std_dev_in_o  avg_out_o  avg_in_o  out_pack_sum_o  \
# 0         0.4325        0.0225     0.6741    0.0419          0.8682
# 1         0.2969        0.0223     0.8333    0.0534          0.9573
# 2         0.4160        0.0192     0.6817    0.0420          0.8744
# 3         0.4341        0.0165     0.6766    0.0398          0.8657
# 4         0.4006        0.0172     0.6811    0.0345          0.8691
#
#    in_pack_num_o  out_pack_num_o  in_pack_ratio_o  out_pack_ratio_o  \
# 0         0.0258          0.1318           0.1153            0.8847
# 1         0.0166          0.0427           0.2600            0.7400
# 2         0.0251          0.1256           0.1195            0.8805
# 3         0.0260          0.1343           0.1132            0.8868
# 4         0.0245          0.1309           0.1090            0.8910
#
#    total_pack_num_o  ...  avg_med_o  sum_burst_med_o  avg_burst_med_o  \
# 0            0.1379  ...     0.0740           0.0015           0.0143
# 1            0.0471  ...     0.0673           0.0005           0.0077
# 2            0.1315  ...     0.0969           0.0017           0.0170
# 3            0.1404  ...     0.1121           0.0022           0.0212
# 4            0.1364  ...     0.0837           0.0017           0.0161
#
#    std_burst_med_o  in_num_30_o  out_num_30_o  in_sum_30_o  out_sum_30_o  \
# 0           0.0141       0.3752        0.6248       0.4615        0.5385
# 1           0.0069       0.3752        0.6248       0.4615        0.5385
# 2           0.0155       0.3133        0.6886       0.4667        0.5333
# 3           0.0215       0.3752        0.6248       0.4615        0.5385
# 4           0.0163       0.3752        0.6248       0.4615        0.5385
#
#    total_sum_pack_per_sec_o  total_num_pack_per_sec_o
# 0                    0.7140                    0.2240
# 1                    0.7768                    0.2082
# 2                    0.7758                    0.1714
# 3                    0.7934                    0.1556
# 4                    0.7351                    0.2040
#
# [5 rows x 24 columns]

# %%
#정규화 하기 전 데이터
constant_c.to_csv('no_nor_constant_c.csv', index=False)
constant_o.to_csv('no_nor_constant_o.csv', index=False)

# %%
#bound, 정규화
from sklearn.preprocessing import MinMaxScaler

# MinMaxScaler를 각 열에 따로 적용하여 기존 데이터프레임에 넣어줌
scaler = MinMaxScaler()

for i, column in enumerate(constant_c.columns):
        column_data = constant_c[column].values.reshape(-1, 1)  # 열 벡터로 변환
        constant_c[column] = scaler.fit_transform(column_data)  # 정규화된 값으로 열 대체
        column_data = constant_c[column].values.reshape(-1, 1)  # 열 벡터로 변환
        constant_c[column] = np.round(constant_c[column], 4)  # 소수점 셋째 자리까지 반올림하여 저장

for i, column in enumerate(constant_o.columns):
        column_data = constant_o[column].values.reshape(-1, 1)  # 열 벡터로 변환
        constant_o[column] = scaler.fit_transform(column_data)  # 정규화된 값으로 열 대체
        column_data = constant_o[column].values.reshape(-1, 1)  # 열 벡터로 변환
        constant_o[column] = np.round(constant_o[column], 4)  # 소수점 셋째 자리까지 반올림하여 저장

# %%
#정규화 하기 전 데이터
constant_c.to_csv('nor_constant_c.csv', index=False)
constant_o.to_csv('nor_constant_o.csv', index=False)

# %%
y_mul.to_csv('y_mul',index = False)
